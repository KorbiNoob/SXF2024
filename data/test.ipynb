# %%
import json
from uuid import uuid4
import os
with open("database.json", mode="r") as f:
    dic = json.load(f)
valid_ids = list(map(lambda x: x.split(".")[0],os.listdir("../static/photos/")))

# %%
dic
# Out:
# [{'name': 'Hans Müller',
#   'position': 'Bürgermeister',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Hans Müller ist seit 2015 Bürgermeister und bekannt für seine Bemühungen im Umweltschutz und der Verkehrsplanung.',
#   'constituency': 'München-Mitte',
#   'history': [{'kind': 'muellerfan1',
#     'content': 'Bürgermeister Müller hat viel für den Umweltschutz getan.'},
#    {'kind': 'greenlover99',
#     'content': 'Die Verkehrsplanung in München-Mitte hat sich unter Müller stark verbessert.'}],
#   'photo': 'standard'},
#  {'name': 'Claudia Schmidt',
#   'position': 'Stadträtin',
#   'party': 'Christlich-Soziale Union (CSU)',
#   'biography': 'Claudia Schmidt ist seit 2018 Stadträtin und setzt sich für die Belange der Familien und Kinder ein.',
#   'constituency': 'München-Schwabing',
#   'history': [{'kind': 'familyfirst',
#     'content': 'Stadträtin Schmidt ist eine wahre Vertreterin der Familien.'},
#    {'kind': 'schwabingmom',
#     'content': 'Claudia Schmidt setzt sich unermüDIE LINKEich für die Kinder in unserer Stadt ein.'}],
#   'photo': 'standard'},
#  {'name': 'Peter Braun',
#   'position': 'Bezirksleiter',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'biography': 'Peter Braun ist ein erfahrener Bezirksleiter, der für seine Initiativen im Bereich erneuerbare Energien bekannt ist.',
#   'constituency': 'München-Ramersdorf',
#   'history': [{'kind': 'eco-warrior',
#     'content': 'Peter Braun bringt frischen Wind in die Energiedebatte.'},
#    {'kind': 'greenfuture',
#     'content': 'Erneuerbare Energien sind dank Braun auf dem Vormarsch in Ramersdorf.'}],
#   'photo': 'standard'},
#  {'name': 'Sabine Fischer',
#   'position': 'Abgeordnete',
#   'party': 'Freie Wähler',
#   'biography': 'Sabine Fischer ist seit 2020 Abgeordnete und bekannt für ihre Arbeit in der Bildungsreform.',
#   'constituency': 'München-Pasing',
#   'history': [{'kind': 'edu-supporter',
#     'content': 'Fischer hat viel für die Bildungsreform getan.'},
#    {'kind': 'pasingparent',
#     'content': 'Die Schulen in Pasing sind dank Fischer besser geworden.'}],
#   'photo': 'standard'},
#  {'name': 'Thomas Weber',
#   'position': 'Ortsvorsteher',
#   'party': 'Alternative für Deutschland (AfD)',
#   'biography': 'Thomas Weber ist Ortsvorsteher und setzt sich für eine strengere Sicherheitspolitik ein.',
#   'constituency': 'München-Moosach',
#   'history': [{'kind': 'moosachlocal',
#     'content': 'Weber sorgt für mehr Sicherheit in Moosach.'},
#    {'kind': 'securityfirst',
#     'content': 'Dank Weber fühlen wir uns sicherer in Moosach.'}],
#   'photo': 'standard'},
#  {'name': 'Julia König',
#   'position': 'Gemeinderätin',
#   'party': 'Parteilos',
#   'biography': 'Julia König ist seit 2019 Gemeinderätin und engagiert sich stark für soziale Gerechtigkeit.',
#   'constituency': 'München-Milbertshofen',
#   'history': [{'kind': 'justice4all',
#     'content': 'König kämpft unermüDIE LINKEich für soziale Gerechtigkeit.'},
#    {'kind': 'milbertsupport',
#     'content': 'Dank König geht es sozial gerecht zu in Milbertshofen.'}],
#   'photo': 'standard'},
#  {'name': 'Martin Schulze',
#   'position': 'Landtagsabgeordneter',
#   'party': 'DIE LINKE',
#   'biography': 'Martin Schulze ist Landtagsabgeordneter seit 2016 und bekannt für seine Initiativen im Bereich Wirtschaftsförderung.',
#   'constituency': 'München-Giesing',
#   'history': [{'kind': 'quote',
#     'header': 'Ein Zitat des Bürgermeisters',
#     'content': 'Schulze fördert die lokale Wirtschaft.'},
#    {'kind': 'quote',
#     'header': 'Ein weiteres Zitat des Bürgermeisters',
#     'content': 'Dank Schulze boomt die Wirtschaft in Giesing.'},
#    {'kind': 'audio',
#     'header': 'Das Lieblingslied des Schulzes',
#     'content': 'pedro'},
#    {'kind': 'video', 'header': 'Ein Video des Schulzes', 'content': 'pedro'}],
#   'photo': '02c060e5-6119-4d34-b60d-b05fa0b5e7ab'},
#  {'name': 'Anja Becker',
#   'position': 'Bürgermeisterin',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Anja Becker ist seit 2021 Bürgermeisterin und bekannt für ihre Maßnahmen zur Verbesserung der Infrastruktur.',
#   'constituency': 'München-Bogenhausen',
#   'history': [{'kind': 'bogefan',
#     'content': 'Bürgermeisterin Becker verbessert die Infrastruktur in Bogenhausen.'},
#    {'kind': 'betterroads',
#     'content': 'Dank Becker sind die Straßen in Bogenhausen besser geworden.'}],
#   'photo': 'standard'},
#  {'name': 'Uwe Klein',
#   'position': 'Stadtrat',
#   'party': 'Christlich-Soziale Union (CSU)',
#   'biography': 'Uwe Klein ist seit 2017 Stadtrat und setzt sich für die Förderung des öffentlichen Nahverkehrs ein.',
#   'constituency': 'München-Hadern',
#   'history': [{'kind': 'transitlover',
#     'content': 'Stadtrat Klein verbessert den Nahverkehr in Hadern.'},
#    {'kind': 'publictransitfan',
#     'content': 'Dank Klein fahren die Busse und Bahnen besser.'}],
#   'photo': 'standard'},
#  {'name': 'Katrin Meier',
#   'position': 'Abgeordnete',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'biography': 'Katrin Meier ist seit 2022 Abgeordnete und bekannt für ihre umweltpolitischen Initiativen.',
#   'constituency': 'München-Mitte',
#   'history': [{'kind': 'greenmeier',
#     'content': 'Meier bringt Umweltbewusstsein in die Politik.'},
#    {'kind': 'ecoactivist', 'content': 'Dank Meier wird unsere Stadt grüner.'}],
#   'photo': 'standard'},
#  {'name': 'Johannes Berger',
#   'position': 'Bezirksleiter',
#   'party': 'Freie Wähler',
#   'biography': 'Johannes Berger ist ein engagierter Bezirksleiter, der sich für die Verbesserung der Bildungsinfrastruktur einsetzt.',
#   'constituency': 'München-Schwabing',
#   'history': [{'kind': 'schwabingstudent',
#     'content': 'Berger hat die Schulen in Schwabing modernisiert.'},
#    {'kind': 'eduadvocate',
#     'content': 'Dank Berger sind unsere Schulen besser ausgestattet.'}],
#   'photo': 'standard'},
#  {'name': 'Lisa Frank',
#   'position': 'Gemeinderätin',
#   'party': 'DIE LINKE',
#   'biography': 'Lisa Frank ist seit 2023 Gemeinderätin und bekannt für ihre Initiativen im Bereich Kulturförderung.',
#   'constituency': 'München-Ramersdorf',
#   'history': [{'kind': 'culturefan',
#     'content': 'Frank hat viel für die Kultur in Ramersdorf getan.'},
#    {'kind': 'ramersdorfculture',
#     'content': 'Dank Frank blüht die Kultur in unserer Gemeinde auf.'}],
#   'photo': 'standard'},
#  {'name': 'Maximilian Huber',
#   'position': 'Landtagsabgeordneter',
#   'party': 'Alternative für Deutschland (AfD)',
#   'biography': 'Maximilian Huber ist seit 2019 Landtagsabgeordneter und setzt sich für eine restriktive Migrationspolitik ein.',
#   'constituency': 'München-Pasing',
#   'history': [{'kind': 'pasingpatriot',
#     'content': 'Huber setzt sich für eine strengere Migrationspolitik ein.'},
#    {'kind': 'safetypasing',
#     'content': 'Dank Huber gibt es mehr Sicherheit in Pasing.'}],
#   'photo': 'standard'},
#  {'name': 'Susanne Richter',
#   'position': 'Bürgermeisterin',
#   'party': 'Parteilos',
#   'biography': 'Susanne Richter ist seit 2020 Bürgermeisterin und engagiert sich stark für den sozialen Wohnungsbau.',
#   'constituency': 'München-Moosach',
#   'history': [{'kind': 'moosachhome',
#     'content': 'Richter baut bezahlbare Wohnungen in Moosach.'},
#    {'kind': 'housingfirst',
#     'content': 'Dank Richter gibt es mehr Sozialwohnungen.'}],
#   'photo': 'standard'},
#  {'name': 'Alexander Wolf',
#   'position': 'Stadtrat',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Alexander Wolf ist seit 2018 Stadtrat und bekannt für seine Initiativen im Bereich Digitalisierung.',
#   'constituency': 'München-Milbertshofen',
#   'history': [{'kind': 'digitalwolf',
#     'content': 'Wolf bringt Digitalisierung voran.'},
#    {'kind': 'techfuture',
#     'content': 'Dank Wolf wird Milbertshofen digitaler.'}],
#   'photo': 'standard'},
#  {'name': 'Marie Bauer',
#   'position': 'Abgeordnete',
#   'party': 'Christlich-Soziale Union (CSU)',
#   'biography': 'Marie Bauer ist seit 2021 Abgeordnete und setzt sich für die Förderung der lokalen Wirtschaft ein.',
#   'constituency': 'München-Giesing',
#   'history': [{'kind': 'wirtschaftfan',
#     'content': 'Bauer unterstützt die lokale Wirtschaft.'},
#    {'kind': 'giesinggrowth',
#     'content': 'Dank Bauer boomt die Wirtschaft in Giesing.'}],
#   'photo': '17325499-3f2e-4f94-a6f3-9e016edf4136'},
#  {'name': 'Robert Fischer',
#   'position': 'Ortsvorsteher',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'biography': 'Robert Fischer ist Ortsvorsteher und bekannt für seine umweltpolitischen Maßnahmen.',
#   'constituency': 'München-Bogenhausen',
#   'history': [{'kind': 'greenfischer',
#     'content': 'Fischer setzt sich für die Umwelt ein.'},
#    {'kind': 'eco-bogenhausen',
#     'content': 'Dank Fischer wird Bogenhausen grüner.'}],
#   'photo': 'standard'},
#  {'name': 'Daniela Wagner',
#   'position': 'Gemeinderätin',
#   'party': 'Freie Wähler',
#   'biography': 'Daniela Wagner ist seit 2019 Gemeinderätin und engagiert sich stark für den Ausbau des öffentlichen Nahverkehrs.',
#   'constituency': 'München-Hadern',
#   'history': [{'kind': 'transitadvocate',
#     'content': 'Wagner verbessert den Nahverkehr in Hadern.'},
#    {'kind': 'publictransportfan',
#     'content': 'Dank Wagner fahren die Busse und Bahnen besser.'}],
#   'photo': 'standard'},
#  {'name': 'Georg Becker',
#   'position': 'Bürgermeister',
#   'party': 'DIE LINKE',
#   'biography': 'Georg Becker ist seit 2022 Bürgermeister und setzt sich für die Modernisierung der städtischen Infrastruktur ein.',
#   'constituency': 'München-Mitte',
#   'history': [{'kind': 'modernbecker',
#     'content': 'Becker modernisiert die Infrastruktur in der Stadt.'},
#    {'kind': 'citydevelopment',
#     'content': 'Dank Becker geht die Stadtentwicklung voran.'}],
#   'photo': 'standard'},
#  {'name': 'Laura Schmidt',
#   'position': 'Stadträtin',
#   'party': 'Alternative für Deutschland (AfD)',
#   'biography': 'Laura Schmidt ist seit 2020 Stadträtin und bekannt für ihre Initiativen zur Verbesserung der inneren Sicherheit.',
#   'constituency': 'München-Schwabing',
#   'history': [{'kind': 'safetyfirst',
#     'content': 'Schmidt setzt sich für mehr Sicherheit in Schwabing ein.'},
#    {'kind': 'securelife',
#     'content': 'Dank Schmidt fühlen wir uns sicherer in Schwabing.'}],
#   'photo': 'standard'},
#  {'name': 'Monika Hoffmann',
#   'position': 'Bezirksleiterin',
#   'party': 'Parteilos',
#   'biography': 'Monika Hoffmann ist seit 2021 Bezirksleiterin und engagiert sich für den Schutz von Minderheiten.',
#   'constituency': 'München-Ramersdorf',
#   'history': [{'kind': 'minoritysupport',
#     'content': 'Hoffmann kämpft für den Schutz von Minderheiten.'},
#    {'kind': 'ramersdorfsupport',
#     'content': 'Dank Hoffmann geht es Minderheiten besser in Ramersdorf.'}],
#   'photo': 'standard'},
#  {'name': 'Lukas Weber',
#   'position': 'Abgeordneter',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Lukas Weber ist seit 2018 Abgeordneter und bekannt für seine Bemühungen im Bereich der Bildungspolitik.',
#   'constituency': 'München-Pasing',
#   'history': [{'kind': 'edu-fan',
#     'content': 'Weber setzt sich für eine bessere Bildung ein.'},
#    {'kind': 'pasingstudent',
#     'content': 'Dank Weber sind die Schulen in Pasing besser.'}],
#   'photo': 'standard'},
#  {'name': 'Karin Keller',
#   'position': 'Ortsvorsteherin',
#   'party': 'Christlich-Soziale Union (CSU)',
#   'biography': 'Karin Keller ist Ortsvorsteherin seit 2019 und bekannt für ihre Initiativen im Bereich Stadtentwicklung.',
#   'constituency': 'München-Moosach',
#   'history': [{'kind': 'citylover',
#     'content': 'Keller bringt die Stadtentwicklung voran.'},
#    {'kind': 'moosachfuture', 'content': 'Dank Keller wird Moosach schöner.'}],
#   'photo': 'standard'},
#  {'name': 'Felix Braun',
#   'position': 'Landtagsabgeordneter',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'biography': 'Felix Braun ist Landtagsabgeordneter seit 2021 und bekannt für seine umweltfreunDIE LINKEichen Verkehrskonzepte.',
#   'constituency': 'München-Milbertshofen',
#   'history': [{'kind': 'greentraffic',
#     'content': 'Braun fördert umweltfreunDIE LINKEiche Verkehrskonzepte.'},
#    {'kind': 'milbertgreen',
#     'content': 'Dank Braun ist der Verkehr in Milbertshofen grüner.'}],
#   'photo': 'standard'},
#  {'name': 'Anna Bergmann',
#   'position': 'Stadträtin',
#   'party': 'Freie Wähler',
#   'biography': 'Anna Bergmann ist seit 2017 Stadträtin und setzt sich für die Förderung von Sport- und Freizeitangeboten ein.',
#   'constituency': 'München-Giesing',
#   'history': [{'kind': 'sportsfan',
#     'content': 'Bergmann fördert Sportangebote in Giesing.'},
#    {'kind': 'giesingfitness',
#     'content': 'Dank Bergmann gibt es mehr Freizeitangebote.'}],
#   'photo': 'a9e1478b-5992-409c-9bc0-305eb0ef5d0f'},
#  {'name': 'Markus Klein',
#   'position': 'Bürgermeister',
#   'party': 'DIE LINKE',
#   'biography': 'Markus Klein ist seit 2019 Bürgermeister und bekannt für seine Initiativen zur Förderung der lokalen Kunstszene.',
#   'constituency': 'München-Bogenhausen',
#   'history': [{'kind': 'artlover',
#     'content': 'Klein fördert die lokale Kunstszene.'},
#    {'kind': 'bogenart',
#     'content': 'Dank Klein blüht die Kunst in Bogenhausen.'}],
#   'photo': 'standard'},
#  {'name': 'Petra Winkler',
#   'position': 'Ortsvorsteherin',
#   'party': 'Alternative für Deutschland (AfD)',
#   'biography': 'Petra Winkler ist seit 2020 Ortsvorsteherin und setzt sich für eine konservative Familienpolitik ein.',
#   'constituency': 'München-Hadern',
#   'history': [{'kind': 'conservativefamily',
#     'content': 'Winkler fördert eine konservative Familienpolitik.'},
#    {'kind': 'familyvalues',
#     'content': 'Dank Winkler werden traditionelle Familienwerte in Hadern gestärkt.'}],
#   'photo': 'standard'},
#  {'name': 'Sophie Schwarz',
#   'position': 'Bezirksleiterin',
#   'party': 'Parteilos',
#   'biography': 'Sophie Schwarz ist Bezirksleiterin seit 2021 und engagiert sich für die Förderung von Kultur- und Jugendprojekten.',
#   'constituency': 'München-Mitte',
#   'history': [{'kind': 'culturefan',
#     'content': 'Schwarz fördert Kultur- und Jugendprojekte.'},
#    {'kind': 'midDIE LINKEeculture',
#     'content': 'Dank Schwarz blühen Kulturprojekte in München-Mitte.'}],
#   'photo': 'standard'},
#  {'name': 'Nina Krüger',
#   'position': 'Abgeordnete',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Nina Krüger ist seit 2019 Abgeordnete und bekannt für ihre Initiativen im Bereich der Gesundheitsversorgung.',
#   'constituency': 'München-Schwabing',
#   'history': [{'kind': 'healthcarefan',
#     'content': 'Krüger setzt sich für bessere Gesundheitsversorgung ein.'},
#    {'kind': 'schwabinghealth',
#     'content': 'Dank Krüger sind die Gesundheitsdienste in Schwabing besser.'}],
#   'photo': 'standard'},
#  {'name': 'Frank Bauer',
#   'position': 'Ortsvorsteher',
#   'party': 'Christlich-Soziale Union (CSU)',
#   'biography': 'Frank Bauer ist seit 2018 Ortsvorsteher und engagiert sich für die Förderung der lokalen Wirtschaft.',
#   'constituency': 'München-Ramersdorf',
#   'history': [{'kind': 'bizsupporter',
#     'content': 'Bauer unterstützt die lokale Wirtschaft in Ramersdorf.'},
#    {'kind': 'ramersdorfboom',
#     'content': 'Dank Bauer boomt die Wirtschaft in Ramersdorf.'}],
#   'photo': 'standard'},
#  {'name': 'Eva König',
#   'position': 'Gemeinderätin',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'biography': 'Eva König ist seit 2020 Gemeinderätin und bekannt für ihre umweltpolitischen Maßnahmen.',
#   'constituency': 'München-Pasing',
#   'history': [{'kind': 'greenqueen',
#     'content': 'König setzt sich für die Umwelt in Pasing ein.'},
#    {'kind': 'eco-pasing', 'content': 'Dank König wird Pasing grüner.'}],
#   'photo': 'standard'},
#  {'name': 'Holger Maier',
#   'position': 'Landtagsabgeordneter',
#   'party': 'Freie Wähler',
#   'biography': 'Holger Maier ist seit 2021 Landtagsabgeordneter und setzt sich für die Verbesserung der Infrastruktur ein.',
#   'constituency': 'München-Moosach',
#   'history': [{'kind': 'infra-fan',
#     'content': 'Maier verbessert die Infrastruktur in Moosach.'},
#    {'kind': 'moosachroads',
#     'content': 'Dank Maier sind die Straßen in Moosach besser.'}],
#   'photo': 'standard'},
#  {'name': 'Ulrike Weber',
#   'position': 'Stadträtin',
#   'party': 'DIE LINKE',
#   'biography': 'Ulrike Weber ist seit 2020 Stadträtin und bekannt für ihre Arbeit im Bereich der Kulturförderung.',
#   'constituency': 'München-Milbertshofen',
#   'history': [{'kind': 'cultureweb',
#     'content': 'Weber fördert die Kultur in Milbertshofen.'},
#    {'kind': 'milbertculture',
#     'content': 'Dank Weber blüht die Kultur in unserer Stadt.'}],
#   'photo': 'standard'},
#  {'name': 'Christian Neumann',
#   'position': 'Bürgermeister',
#   'party': 'Alternative für Deutschland (AfD)',
#   'biography': 'Christian Neumann ist seit 2021 Bürgermeister und bekannt für seine konservativen Initiativen.',
#   'constituency': 'München-Giesing',
#   'history': [{'kind': 'conservativevoice',
#     'content': 'Neumann setzt sich für konservative Werte ein.'},
#    {'kind': 'giesingvalues',
#     'content': 'Dank Neumann werden konservative Werte in Giesing gestärkt.'}],
#   'photo': 'd823effe-1feb-4815-8d09-49e7439f2ff7'},
#  {'name': 'Elena Hoffmann',
#   'position': 'Gemeinderätin',
#   'party': 'Parteilos',
#   'biography': 'Elena Hoffmann ist seit 2022 Gemeinderätin und engagiert sich für soziale Projekte.',
#   'constituency': 'München-Bogenhausen',
#   'history': [{'kind': 'socialsupport',
#     'content': 'Hoffmann fördert soziale Projekte in Bogenhausen.'},
#    {'kind': 'bogensupport',
#     'content': 'Dank Hoffmann gibt es mehr soziale Unterstützung.'}],
#   'photo': 'standard'},
#  {'name': 'Jan Wagner',
#   'position': 'Abgeordneter',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Jan Wagner ist seit 2017 Abgeordneter und bekannt für seine Arbeit im Bereich der Digitalisierung.',
#   'constituency': 'München-Hadern',
#   'history': [{'kind': 'digitalwagner',
#     'content': 'Wagner bringt Digitalisierung voran.'},
#    {'kind': 'techhadern', 'content': 'Dank Wagner wird Hadern digitaler.'}],
#   'photo': 'standard'},
#  {'name': 'Sophia Meier',
#   'position': 'Stadträtin',
#   'party': 'Christlich-Soziale Union (CSU)',
#   'biography': 'Sophia Meier ist seit 2018 Stadträtin und setzt sich für die Förderung von Sport und Freizeit ein.',
#   'constituency': 'München-Mitte',
#   'history': [{'kind': 'sportsfanatic',
#     'content': 'Meier fördert Sportangebote in München-Mitte.'},
#    {'kind': 'fitnessfirst',
#     'content': 'Dank Meier gibt es mehr Sportmöglichkeiten.'}],
#   'photo': 'standard'},
#  {'name': 'Paul Richter',
#   'position': 'Landtagsabgeordneter',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'biography': 'Paul Richter ist Landtagsabgeordneter seit 2020 und bekannt für seine umweltfreunDIE LINKEichen Initiativen.',
#   'constituency': 'München-Schwabing',
#   'history': [{'kind': 'greenpaul',
#     'content': 'Richter setzt sich für die Umwelt ein.'},
#    {'kind': 'eco-schwabing',
#     'content': 'Dank Richter wird Schwabing grüner.'}],
#   'photo': 'standard'},
#  {'name': 'Melanie Schäfer',
#   'position': 'Bezirksleiterin',
#   'party': 'Freie Wähler',
#   'biography': 'Melanie Schäfer ist seit 2021 Bezirksleiterin und engagiert sich stark für die Bildung.',
#   'constituency': 'München-Ramersdorf',
#   'history': [{'kind': 'eduenthusiast',
#     'content': 'Schäfer fördert Bildung in Ramersdorf.'},
#    {'kind': 'ramersdorfedu',
#     'content': 'Dank Schäfer sind die Schulen besser ausgestattet.'}],
#   'photo': 'standard'},
#  {'name': 'Julian Köhler',
#   'position': 'Gemeinderat',
#   'party': 'DIE LINKE',
#   'biography': 'Julian Köhler ist seit 2022 Gemeinderat und bekannt für seine Initiativen im Bereich der Digitalisierung.',
#   'constituency': 'München-Pasing',
#   'history': [{'kind': 'digitalkoehler',
#     'content': 'Köhler bringt Digitalisierung nach Pasing.'},
#    {'kind': 'pasingtech', 'content': 'Dank Köhler wird Pasing digitaler.'}],
#   'photo': 'standard'},
#  {'name': 'Leon Becker',
#   'position': 'Abgeordneter',
#   'party': 'Alternative für Deutschland (AfD)',
#   'biography': 'Leon Becker ist seit 2019 Abgeordneter und setzt sich für eine restriktive Migrationspolitik ein.',
#   'constituency': 'München-Moosach',
#   'history': [{'kind': 'migrationcontrol',
#     'content': 'Becker setzt sich für strengere Migrationsgesetze ein.'},
#    {'kind': 'moosachsecurity',
#     'content': 'Dank Becker gibt es mehr Sicherheit in Moosach.'}],
#   'photo': 'standard'},
#  {'name': 'Nadine Hofmann',
#   'position': 'Bürgermeisterin',
#   'party': 'Parteilos',
#   'biography': 'Nadine Hofmann ist seit 2020 Bürgermeisterin und bekannt für ihre sozialen Projekte.',
#   'constituency': 'München-Milbertshofen',
#   'history': [{'kind': 'socialmayor',
#     'content': 'Hofmann setzt sich für soziale Projekte ein.'},
#    {'kind': 'milberthilfe',
#     'content': 'Dank Hofmann gibt es mehr Unterstützung in Milbertshofen.'}],
#   'photo': 'standard'},
#  {'name': 'Michael Weiß',
#   'position': 'Stadtrat',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Michael Weiß ist seit 2017 Stadtrat und bekannt für seine Initiativen zur Verkehrsplanung.',
#   'constituency': 'München-Giesing',
#   'history': [{'kind': 'trafficplanner',
#     'content': 'Weiß verbessert die Verkehrsplanung in Giesing.'},
#    {'kind': 'giesingtraffic',
#     'content': 'Dank Weiß ist der Verkehr in Giesing besser.'}],
#   'photo': '89a608e2-b44b-47b2-bca2-a8bc50f65946'},
#  {'name': 'Clara Wagner',
#   'position': 'Bezirksleiterin',
#   'party': 'Christlich-Soziale Union (CSU)',
#   'biography': 'Clara Wagner ist seit 2019 Bezirksleiterin und engagiert sich für die Förderung von Startups.',
#   'constituency': 'München-Bogenhausen',
#   'history': [{'kind': 'startupfan',
#     'content': 'Wagner unterstützt Startups in Bogenhausen.'},
#    {'kind': 'bogenstart',
#     'content': 'Dank Wagner gibt es mehr Unterstützung für Startups.'}],
#   'photo': 'standard'},
#  {'name': 'Jonas Berg',
#   'position': 'Landtagsabgeordneter',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'biography': 'Jonas Berg ist Landtagsabgeordneter seit 2021 und bekannt für seine umweltpolitischen Maßnahmen.',
#   'constituency': 'München-Hadern',
#   'history': [{'kind': 'greenberg',
#     'content': 'Berg setzt sich für die Umwelt in Hadern ein.'},
#    {'kind': 'haderngreen', 'content': 'Dank Berg wird Hadern grüner.'}],
#   'photo': 'standard'},
#  {'name': 'Isabel Fischer',
#   'position': 'Gemeinderätin',
#   'party': 'Freie Wähler',
#   'biography': 'Isabel Fischer ist seit 2022 Gemeinderätin und bekannt für ihre Initiativen im Bereich der Bildung.',
#   'constituency': 'München-Mitte',
#   'history': [{'kind': 'eduadvocate',
#     'content': 'Fischer setzt sich für bessere Bildung ein.'},
#    {'kind': 'midDIE LINKEeedu',
#     'content': 'Dank Fischer sind die Schulen in München-Mitte besser.'}],
#   'photo': 'standard'},
#  {'name': 'Tom Keller',
#   'position': 'Bürgermeister',
#   'party': 'DIE LINKE',
#   'biography': 'Tom Keller ist seit 2021 Bürgermeister und bekannt für seine Initiativen zur Wirtschaftsförderung.',
#   'constituency': 'München-Schwabing',
#   'history': [{'kind': 'bizlover',
#     'content': 'Keller unterstützt die Wirtschaft in Schwabing.'},
#    {'kind': 'schwabingboom',
#     'content': 'Dank Keller boomt die Wirtschaft in Schwabing.'}],
#   'photo': 'standard'},
#  {'name': 'Emma Schneider',
#   'position': 'Ortsvorsteherin',
#   'party': 'Alternative für Deutschland (AfD)',
#   'biography': 'Emma Schneider ist seit 2020 Ortsvorsteherin und setzt sich für eine strengere Migrationspolitik ein.',
#   'constituency': 'München-Ramersdorf',
#   'history': [{'kind': 'secureborders',
#     'content': 'Schneider setzt sich für strengere Migrationsgesetze ein.'},
#    {'kind': 'ramersdorfsecurity',
#     'content': 'Dank Schneider gibt es mehr Sicherheit in Ramersdorf.'}],
#   'photo': 'standard'},
#  {'name': 'Oliver Neumann',
#   'position': 'Stadtrat',
#   'party': 'Parteilos',
#   'biography': 'Oliver Neumann ist seit 2022 Stadtrat und bekannt für seine Initiativen zur Förderung der lokalen Kunstszene.',
#   'constituency': 'München-Pasing',
#   'history': [{'kind': 'artlover',
#     'content': 'Neumann unterstützt die Kunst in Pasing.'},
#    {'kind': 'pasingart',
#     'content': 'Dank Neumann blüht die Kunst in Pasing.'}],
#   'photo': 'standard'},
#  {'name': 'Theresa Klein',
#   'position': 'Abgeordnete',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Theresa Klein ist seit 2018 Abgeordnete und bekannt für ihre Initiativen im Bereich der sozialen Gerechtigkeit.',
#   'constituency': 'München-Moosach',
#   'history': [{'kind': 'justicewarrior',
#     'content': 'Klein kämpft für soziale Gerechtigkeit.'},
#    {'kind': 'moosachjustice',
#     'content': 'Dank Klein gibt es mehr Gerechtigkeit in Moosach.'}],
#   'photo': 'standard'},
#  {'name': 'Heike Braun',
#   'position': 'Bezirksleiterin',
#   'party': 'Christlich-Soziale Union (CSU)',
#   'biography': 'Heike Braun ist seit 2020 Bezirksleiterin und engagiert sich für die Förderung der Infrastruktur.',
#   'constituency': 'München-Milbertshofen',
#   'history': [{'kind': 'infrafan',
#     'content': 'Braun verbessert die Infrastruktur in Milbertshofen.'},
#    {'kind': 'milbertinfra',
#     'content': 'Dank Braun sind die Straßen und Brücken besser.'}],
#   'photo': 'standard'},
#  {'name': 'Sven Meier',
#   'position': 'Stadtrat',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'biography': 'Sven Meier ist seit 2021 Stadtrat und bekannt für seine umweltfreunDIE LINKEichen Initiativen.',
#   'constituency': 'München-Giesing',
#   'history': [{'kind': 'greenmeier',
#     'content': 'Meier setzt sich für die Umwelt ein.'},
#    {'kind': 'giesinggreen', 'content': 'Dank Meier wird Giesing grüner.'}],
#   'photo': '7766051e-759b-4483-be2a-d27fd8522b3f'},
#  {'name': 'Lena Bergmann',
#   'position': 'Gemeinderätin',
#   'party': 'Freie Wähler',
#   'biography': 'Lena Bergmann ist seit 2021 Gemeinderätin und bekannt für ihre Initiativen im Bereich Bildung.',
#   'constituency': 'München-Bogenhausen',
#   'history': [{'kind': 'educationfan',
#     'content': 'Bergmann setzt sich für bessere Bildung ein.'},
#    {'kind': 'bogenedu',
#     'content': 'Dank Bergmann sind die Schulen in Bogenhausen besser.'}],
#   'photo': 'standard'},
#  {'name': 'David Wolf',
#   'position': 'Bürgermeister',
#   'party': 'DIE LINKE',
#   'biography': 'David Wolf ist seit 2020 Bürgermeister und bekannt für seine wirtschaftspolitischen Initiativen.',
#   'constituency': 'München-Hadern',
#   'history': [{'kind': 'businesswolf',
#     'content': 'Wolf fördert die Wirtschaft in Hadern.'},
#    {'kind': 'hadernbiz',
#     'content': 'Dank Wolf boomt die Wirtschaft in Hadern.'}],
#   'photo': 'standard'},
#  {'name': 'Anna Lang',
#   'position': 'Bürgermeisterin',
#   'party': 'Christlich-Soziale Union (CSU)',
#   'biography': 'Anna Lang ist seit 2022 Bürgermeisterin und setzt sich für die Förderung der Digitalisierung in der Stadtverwaltung ein.',
#   'constituency': 'München-Altstadt',
#   'history': [{'kind': 'digitalleader',
#     'content': 'Lang bringt Digitalisierung in die Stadtverwaltung.'},
#    {'kind': 'altstadttech',
#     'content': 'Dank Lang sind die digitalen Dienstleistungen in Altstadt verbessert worden.'}],
#   'photo': 'standard'},
#  {'name': 'Tobias Schmidt',
#   'position': 'Stadtrat',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Tobias Schmidt ist seit 2019 Stadtrat und engagiert sich für die Verbesserung der Luftqualität in der Stadt.',
#   'constituency': 'München-Ludwigsvorstadt',
#   'history': [{'kind': 'cleanairfan',
#     'content': 'Schmidt arbeitet hart an der Verbesserung der Luftqualität.'},
#    {'kind': 'ludwigair',
#     'content': 'Dank Schmidt ist die Luft in Ludwigsvorstadt sauberer geworden.'}],
#   'photo': 'standard'},
#  {'name': 'Sophie Peters',
#   'position': 'Bezirksleiterin',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'biography': 'Sophie Peters ist seit 2021 Bezirksleiterin und bekannt für ihre Bemühungen um nachhaltige Stadtentwicklung.',
#   'constituency': 'München-Neuperlach',
#   'history': [{'kind': 'sustainabilityfan',
#     'content': 'Peters setzt sich für nachhaltige Stadtentwicklung ein.'},
#    {'kind': 'neuperlachgreen',
#     'content': 'Dank Peters wird Neuperlach grüner und nachhaltiger.'}],
#   'photo': 'standard'},
#  {'name': 'Leonard Müller',
#   'position': 'Abgeordneter',
#   'party': 'Freie Wähler',
#   'biography': 'Leonard Müller ist seit 2020 Abgeordneter und bekannt für seine Initiativen zur Förderung von Startups.',
#   'constituency': 'München-Pasing',
#   'history': [{'kind': 'startupsupporter',
#     'content': 'Müller fördert Startups in Pasing.'},
#    {'kind': 'pasingstartups',
#     'content': 'Dank Müller gibt es mehr Unterstützung für junge Unternehmen.'}],
#   'photo': 'standard'},
#  {'name': 'Jana Wolf',
#   'position': 'Ortsvorsteherin',
#   'party': 'Parteilos',
#   'biography': 'Jana Wolf ist seit 2021 Ortsvorsteherin und engagiert sich für die Verbesserung der sozialen Infrastruktur.',
#   'constituency': 'München-Ramersdorf',
#   'history': [{'kind': 'socialimprovements',
#     'content': 'Wolf verbessert die soziale Infrastruktur in Ramersdorf.'},
#    {'kind': 'ramersdorfhelp',
#     'content': 'Dank Wolf gibt es mehr soziale Unterstützung in unserer Gemeinde.'}],
#   'photo': 'standard'},
#  {'name': 'Maximilian Köhler',
#   'position': 'Gemeinderat',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Maximilian Köhler ist seit 2022 Gemeinderat und bekannt für seine Arbeit im Bereich der Jugendförderung.',
#   'constituency': 'München-Schwabing',
#   'history': [{'kind': 'youthsupporter',
#     'content': 'Köhler setzt sich stark für die Jugendförderung ein.'},
#    {'kind': 'schwabingyouth',
#     'content': 'Dank Köhler gibt es mehr Angebote für die Jugend in Schwabing.'}],
#   'photo': 'standard'},
#  {'name': 'Elena Zimmermann',
#   'position': 'Stadträtin',
#   'party': 'Christlich-Soziale Union (CSU)',
#   'biography': 'Elena Zimmermann ist seit 2018 Stadträtin und setzt sich für die Verbesserung der Bildungseinrichtungen ein.',
#   'constituency': 'München-Altstadt',
#   'history': [{'kind': 'educationfan',
#     'content': 'Zimmermann arbeitet an der Verbesserung der Bildungseinrichtungen.'},
#    {'kind': 'altstadtedu',
#     'content': 'Dank Zimmermann sind die Schulen in Altstadt besser ausgestattet.'}],
#   'photo': 'standard'},
#  {'name': 'David Huber',
#   'position': 'Bezirksleiter',
#   'party': 'DIE LINKE',
#   'biography': 'David Huber ist seit 2019 Bezirksleiter und bekannt für seine Initiativen zur Förderung der kulturellen Bildung.',
#   'constituency': 'München-Neuperlach',
#   'history': [{'kind': 'cultureeducator',
#     'content': 'Huber fördert kulturelle Bildungsprojekte.'},
#    {'kind': 'neuperlachart',
#     'content': 'Dank Huber gibt es mehr kulturelle Angebote in Neuperlach.'}],
#   'photo': 'standard'},
#  {'name': 'Verena Schuster',
#   'position': 'Abgeordnete',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'biography': 'Verena Schuster ist seit 2020 Abgeordnete und bekannt für ihre Arbeit im Bereich der Nachhaltigkeit.',
#   'constituency': 'München-Giesing',
#   'history': [{'kind': 'sustainabilityadvocate',
#     'content': 'Schuster setzt sich für Nachhaltigkeit ein.'},
#    {'kind': 'giesingsustain',
#     'content': 'Dank Schuster wird Giesing nachhaltiger.'}],
#   'photo': '53cf3b58-21a1-45ec-ad8c-6977a6d9bbfa'},
#  {'name': 'Felix Neumann',
#   'position': 'Landtagsabgeordneter',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Felix Neumann ist seit 2021 Landtagsabgeordneter und setzt sich für die Förderung der lokalen Wirtschaft ein.',
#   'constituency': 'München-Moosach',
#   'history': [{'kind': 'economiChristlich-Soziale Union (CSU)pport',
#     'content': 'Neumann unterstützt die lokale Wirtschaft in Moosach.'},
#    {'kind': 'moosachgrowth',
#     'content': 'Dank Neumann boomt die Wirtschaft in Moosach.'}],
#   'photo': 'standard'},
#  {'name': 'Claudia Braun',
#   'position': 'Bürgermeisterin',
#   'party': 'Christlich-Soziale Union (CSU)',
#   'biography': 'Claudia Braun ist seit 2022 Bürgermeisterin und setzt sich für die Verbesserung der Infrastruktur und der Verkehrsanbindungen ein.',
#   'constituency': 'München-Ludwigsvorstadt',
#   'history': [{'kind': 'infrastructureadvocate',
#     'content': 'Braun arbeitet an der Verbesserung der Infrastruktur.'},
#    {'kind': 'ludwigimprovements',
#     'content': 'Dank Braun sind die Verkehrsanbindungen in Ludwigsvorstadt besser geworden.'}],
#   'photo': 'standard'},
#  {'name': 'Sarah Keller',
#   'position': 'Stadträtin',
#   'party': 'Parteilos',
#   'biography': 'Sarah Keller ist seit 2021 Stadträtin und bekannt für ihre Initiativen im Bereich der sozialen Integration.',
#   'constituency': 'München-Ramersdorf',
#   'history': [{'kind': 'integrationfan',
#     'content': 'Keller setzt sich für soziale Integration ein.'},
#    {'kind': 'ramersdorfintegration',
#     'content': 'Dank Keller gibt es mehr Integrationsangebote in Ramersdorf.'}],
#   'photo': 'standard'},
#  {'name': 'Markus Schiller',
#   'position': 'Ortsvorsteher',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'biography': 'Markus Schiller ist seit 2020 Ortsvorsteher und engagiert sich für den Ausbau von Freizeitangeboten.',
#   'constituency': 'München-Milbertshofen',
#   'history': [{'kind': 'leisureenthusiast',
#     'content': 'Schiller fördert Freizeitangebote in Milbertshofen.'},
#    {'kind': 'milbertfun',
#     'content': 'Dank Schiller gibt es mehr Freizeitmöglichkeiten in Milbertshofen.'}],
#   'photo': 'standard'},
#  {'name': 'Laura Müller',
#   'position': 'Gemeinderätin',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Laura Müller ist seit 2019 Gemeinderätin und bekannt für ihre Arbeit im Bereich der Stadtentwicklung.',
#   'constituency': 'München-Schwabing',
#   'history': [{'kind': 'cityplanner',
#     'content': 'Müller arbeitet an der Stadtentwicklung in Schwabing.'},
#    {'kind': 'schwabinggrowth',
#     'content': 'Dank Müller entwickelt sich Schwabing weiter.'}],
#   'photo': 'standard'},
#  {'name': 'Nicolas Hoffmann',
#   'position': 'Bezirksleiter',
#   'party': 'Christlich-Soziale Union (CSU)',
#   'biography': 'Nicolas Hoffmann ist seit 2020 Bezirksleiter und setzt sich für den Ausbau der Bildungsangebote ein.',
#   'constituency': 'München-Giesing',
#   'history': [{'kind': 'educationadvocate',
#     'content': 'Hoffmann fördert Bildungsangebote in Giesing.'},
#    {'kind': 'giesingeducation',
#     'content': 'Dank Hoffmann gibt es bessere Bildungsangebote in Giesing.'}],
#   'photo': '715723ca-2f23-45cd-a654-cad79e310016'},
#  {'name': 'Hannah Fischer',
#   'position': 'Abgeordnete',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'biography': 'Hannah Fischer ist seit 2021 Abgeordnete und bekannt für ihre Arbeit im Bereich der Umweltpolitik.',
#   'constituency': 'München-Pasing',
#   'history': [{'kind': 'environmentalist',
#     'content': 'Fischer setzt sich für Umweltpolitik ein.'},
#    {'kind': 'pasinggreen',
#     'content': 'Dank Fischer ist Pasing umweltfreunDIE LINKEicher geworden.'}],
#   'photo': 'standard'},
#  {'name': 'Tom Wagner',
#   'position': 'Landtagsabgeordneter',
#   'party': 'Freie Wähler',
#   'biography': 'Tom Wagner ist seit 2022 Landtagsabgeordneter und engagiert sich für die Förderung des länDIE LINKEichen Raums.',
#   'constituency': 'München-Ramersdorf',
#   'history': [{'kind': 'ruraladvocate',
#     'content': 'Wagner setzt sich für die Förderung des länDIE LINKEichen Raums ein.'},
#    {'kind': 'ramersdorfsupport',
#     'content': 'Dank Wagner gibt es mehr Unterstützung für den länDIE LINKEichen Raum in Ramersdorf.'}],
#   'photo': 'standard'},
#  {'name': 'Elena Weber',
#   'position': 'Bürgermeisterin',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Elena Weber ist seit 2023 Bürgermeisterin und setzt sich für eine gerechte Stadtentwicklung ein.',
#   'constituency': 'München-Schwabing',
#   'history': [{'kind': 'justcity',
#     'content': 'Weber arbeitet an einer gerechteren Stadtentwicklung.'},
#    {'kind': 'schwabingjustice',
#     'content': 'Dank Weber gibt es gerechtere Entwicklungsprojekte in Schwabing.'}],
#   'photo': 'standard'},
#  {'name': 'Paul Berger',
#   'position': 'Stadtrat',
#   'party': 'Christlich-Soziale Union (CSU)',
#   'biography': 'Paul Berger ist seit 2022 Stadtrat und bekannt für seine Arbeit im Bereich der Verkehrspolitik.',
#   'constituency': 'München-Altstadt',
#   'history': [{'kind': 'transportadvocate',
#     'content': 'Berger setzt sich für eine bessere Verkehrspolitik ein.'},
#    {'kind': 'altstadttraffic',
#     'content': 'Dank Berger hat sich der Verkehr in Altstadt verbessert.'}],
#   'photo': 'standard'},
#  {'name': 'Lisa Hoffmann',
#   'position': 'Bezirksleiterin',
#   'party': 'Parteilos',
#   'biography': 'Lisa Hoffmann ist seit 2021 Bezirksleiterin und engagiert sich für die Integration von Migranten.',
#   'constituency': 'München-Neuperlach',
#   'history': [{'kind': 'migrantintegration',
#     'content': 'Hoffmann setzt sich für die Integration von Migranten ein.'},
#    {'kind': 'neuperlachintegration',
#     'content': 'Dank Hoffmann gibt es mehr Integrationsangebote in Neuperlach.'}],
#   'photo': 'standard'},
#  {'name': 'Julius König',
#   'position': 'Abgeordneter',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'biography': 'Julius König ist seit 2021 Abgeordneter und bekannt für seine Initiativen im Bereich des sozialen Wohnungsbaus.',
#   'constituency': 'München-Pasing',
#   'history': [{'kind': 'housingadvocate',
#     'content': 'König arbeitet am sozialen Wohnungsbau.'},
#    {'kind': 'pasinghousing',
#     'content': 'Dank König gibt es mehr soziale Wohnungen in Pasing.'}],
#   'photo': 'standard'},
#  {'name': 'Miriam Schneider',
#   'position': 'Landtagsabgeordnete',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Miriam Schneider ist seit 2018 Landtagsabgeordnete und engagiert sich für die Verbesserung des Gesundheitswesens.',
#   'constituency': 'München-Milbertshofen',
#   'history': [{'kind': 'healthcareadvocate',
#     'content': 'Schneider setzt sich für bessere Gesundheitsversorgung ein.'},
#    {'kind': 'milberthealth',
#     'content': 'Dank Schneider ist die Gesundheitsversorgung in Milbertshofen besser geworden.'}],
#   'photo': 'standard'},
#  {'name': 'Thomas Müller',
#   'position': 'Ortsvorsteher',
#   'party': 'Christlich-Soziale Union (CSU)',
#   'biography': 'Thomas Müller ist seit 2021 Ortsvorsteher und bekannt für seine Arbeit im Bereich der Stadtplanung.',
#   'constituency': 'München-Giesing',
#   'history': [{'kind': 'cityplanner',
#     'content': 'Müller arbeitet an der Stadtplanung in Giesing.'},
#    {'kind': 'giesingplanning',
#     'content': 'Dank Müller gibt es bessere Stadtplanung in Giesing.'}],
#   'photo': '10782899-2e91-4769-baed-25aae17a1839'},
#  {'name': 'Nina Fischer',
#   'position': 'Gemeinderätin',
#   'party': 'Freie Wähler',
#   'biography': 'Nina Fischer ist seit 2020 Gemeinderätin und setzt sich für die Förderung der lokalen Kultur ein.',
#   'constituency': 'München-Schwabing',
#   'history': [{'kind': 'culturefan',
#     'content': 'Fischer fördert lokale Kultur in Schwabing.'},
#    {'kind': 'schwabingculture',
#     'content': 'Dank Fischer gibt es mehr kulturelle Angebote in Schwabing.'}],
#   'photo': 'standard'},
#  {'name': 'Lukas Braun',
#   'position': 'Stadtrat',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Lukas Braun ist seit 2021 Stadtrat und bekannt für seine Arbeit im Bereich der Energiepolitik.',
#   'constituency': 'München-Moosach',
#   'history': [{'kind': 'energysupporter',
#     'content': 'Braun setzt sich für bessere Energiepolitik ein.'},
#    {'kind': 'moosachenergy',
#     'content': 'Dank Braun gibt es nachhaltigere Energiequellen in Moosach.'}],
#   'photo': 'standard'},
#  {'name': 'Marlene Weber',
#   'position': 'Bürgermeisterin',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'biography': 'Marlene Weber ist seit 2022 Bürgermeisterin und engagiert sich für den Ausbau der sozialen Einrichtungen.',
#   'constituency': 'München-Ludwigsvorstadt',
#   'history': [{'kind': 'socialfacilities',
#     'content': 'Weber arbeitet am Ausbau sozialer Einrichtungen.'},
#    {'kind': 'ludwigsocial',
#     'content': 'Dank Weber gibt es mehr soziale Einrichtungen in Ludwigsvorstadt.'}],
#   'photo': 'standard'},
#  {'name': 'Jakob Schmidt',
#   'position': 'Bezirksleiter',
#   'party': 'Freie Wähler',
#   'biography': 'Jakob Schmidt ist seit 2019 Bezirksleiter und bekannt für seine Arbeit im Bereich der Verkehrsplanung.',
#   'constituency': 'München-Pasing',
#   'history': [{'kind': 'transportplanner',
#     'content': 'Schmidt arbeitet an der Verkehrsplanung in Pasing.'},
#    {'kind': 'pasingtraffic',
#     'content': 'Dank Schmidt gibt es bessere Verkehrslösungen in Pasing.'}],
#   'photo': 'standard'},
#  {'name': 'Friedrich Meyer',
#   'position': 'Abgeordneter',
#   'party': 'Christlich-Soziale Union (CSU)',
#   'biography': 'Friedrich Meyer ist seit 2020 Abgeordneter und setzt sich für den Ausbau der Infrastruktur ein.',
#   'constituency': 'München-Milbertshofen',
#   'history': [{'kind': 'infrastructurefan',
#     'content': 'Meyer fördert den Ausbau der Infrastruktur.'},
#    {'kind': 'milbertinfrastructure',
#     'content': 'Dank Meyer gibt es mehr Infrastrukturprojekte in Milbertshofen.'}],
#   'photo': 'standard'},
#  {'name': 'Hannah Berger',
#   'position': 'Stadträtin',
#   'party': 'Parteilos',
#   'biography': 'Hannah Berger ist seit 2021 Stadträtin und bekannt für ihre Initiativen im Bereich der Jugendförderung.',
#   'constituency': 'München-Ramersdorf',
#   'history': [{'kind': 'youthinitiatives',
#     'content': 'Berger setzt sich für mehr Jugendförderung ein.'},
#    {'kind': 'ramersdorfyouth',
#     'content': 'Dank Berger gibt es mehr Angebote für die Jugend in Ramersdorf.'}],
#   'photo': 'standard'},
#  {'name': 'Alexander Lang',
#   'position': 'Ortsvorsteher',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Alexander Lang ist seit 2018 Ortsvorsteher und engagiert sich für die Förderung der lokalen Wirtschaft.',
#   'constituency': 'München-Schwabing',
#   'history': [{'kind': 'localeconomics',
#     'content': 'Lang fördert die lokale Wirtschaft in Schwabing.'},
#    {'kind': 'schwabinggrowth',
#     'content': 'Dank Lang hat sich die Wirtschaft in Schwabing verbessert.'}],
#   'photo': 'standard'},
#  {'name': 'Amelie Fischer',
#   'position': 'Gemeinderätin',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'biography': 'Amelie Fischer ist seit 2022 Gemeinderätin und setzt sich für nachhaltige Stadtentwicklung ein.',
#   'constituency': 'München-Neuperlach',
#   'history': [{'kind': 'sustainabledevelopment',
#     'content': 'Fischer arbeitet an nachhaltiger Stadtentwicklung.'},
#    {'kind': 'neuperlachsustainability',
#     'content': 'Dank Fischer gibt es nachhaltige Projekte in Neuperlach.'}],
#   'photo': 'standard'}]

# %%
for entry in dic:
    # print(entry["history"])
    for h in entry["history"]:
        h["kind"] = "quote"
        h["header"] = "Ein Zitat des Politikers"

# %%
dic
# Out:
# [{'name': 'Hans Müller',
#   'position': 'Bürgermeister',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Hans Müller ist seit 2015 Bürgermeister und bekannt für seine Bemühungen im Umweltschutz und der Verkehrsplanung.',
#   'constituency': 'München-Mitte',
#   'history': [{'kind': 'quote',
#     'content': 'Bürgermeister Müller hat viel für den Umweltschutz getan.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Die Verkehrsplanung in München-Mitte hat sich unter Müller stark verbessert.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Claudia Schmidt',
#   'position': 'Stadträtin',
#   'party': 'Christlich-Soziale Union (CSU)',
#   'biography': 'Claudia Schmidt ist seit 2018 Stadträtin und setzt sich für die Belange der Familien und Kinder ein.',
#   'constituency': 'München-Schwabing',
#   'history': [{'kind': 'quote',
#     'content': 'Stadträtin Schmidt ist eine wahre Vertreterin der Familien.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Claudia Schmidt setzt sich unermüDIE LINKEich für die Kinder in unserer Stadt ein.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Peter Braun',
#   'position': 'Bezirksleiter',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'biography': 'Peter Braun ist ein erfahrener Bezirksleiter, der für seine Initiativen im Bereich erneuerbare Energien bekannt ist.',
#   'constituency': 'München-Ramersdorf',
#   'history': [{'kind': 'quote',
#     'content': 'Peter Braun bringt frischen Wind in die Energiedebatte.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Erneuerbare Energien sind dank Braun auf dem Vormarsch in Ramersdorf.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Sabine Fischer',
#   'position': 'Abgeordnete',
#   'party': 'Freie Wähler',
#   'biography': 'Sabine Fischer ist seit 2020 Abgeordnete und bekannt für ihre Arbeit in der Bildungsreform.',
#   'constituency': 'München-Pasing',
#   'history': [{'kind': 'quote',
#     'content': 'Fischer hat viel für die Bildungsreform getan.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Die Schulen in Pasing sind dank Fischer besser geworden.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Thomas Weber',
#   'position': 'Ortsvorsteher',
#   'party': 'Alternative für Deutschland (AfD)',
#   'biography': 'Thomas Weber ist Ortsvorsteher und setzt sich für eine strengere Sicherheitspolitik ein.',
#   'constituency': 'München-Moosach',
#   'history': [{'kind': 'quote',
#     'content': 'Weber sorgt für mehr Sicherheit in Moosach.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Weber fühlen wir uns sicherer in Moosach.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Julia König',
#   'position': 'Gemeinderätin',
#   'party': 'Parteilos',
#   'biography': 'Julia König ist seit 2019 Gemeinderätin und engagiert sich stark für soziale Gerechtigkeit.',
#   'constituency': 'München-Milbertshofen',
#   'history': [{'kind': 'quote',
#     'content': 'König kämpft unermüDIE LINKEich für soziale Gerechtigkeit.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank König geht es sozial gerecht zu in Milbertshofen.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Martin Schulze',
#   'position': 'Landtagsabgeordneter',
#   'party': 'DIE LINKE',
#   'biography': 'Martin Schulze ist Landtagsabgeordneter seit 2016 und bekannt für seine Initiativen im Bereich Wirtschaftsförderung.',
#   'constituency': 'München-Giesing',
#   'history': [{'kind': 'quote',
#     'header': 'Ein Zitat des Politikers',
#     'content': 'Schulze fördert die lokale Wirtschaft.'},
#    {'kind': 'quote',
#     'header': 'Ein Zitat des Politikers',
#     'content': 'Dank Schulze boomt die Wirtschaft in Giesing.'},
#    {'kind': 'quote', 'header': 'Ein Zitat des Politikers', 'content': 'pedro'},
#    {'kind': 'quote',
#     'header': 'Ein Zitat des Politikers',
#     'content': 'pedro'}],
#   'photo': '02c060e5-6119-4d34-b60d-b05fa0b5e7ab'},
#  {'name': 'Anja Becker',
#   'position': 'Bürgermeisterin',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Anja Becker ist seit 2021 Bürgermeisterin und bekannt für ihre Maßnahmen zur Verbesserung der Infrastruktur.',
#   'constituency': 'München-Bogenhausen',
#   'history': [{'kind': 'quote',
#     'content': 'Bürgermeisterin Becker verbessert die Infrastruktur in Bogenhausen.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Becker sind die Straßen in Bogenhausen besser geworden.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Uwe Klein',
#   'position': 'Stadtrat',
#   'party': 'Christlich-Soziale Union (CSU)',
#   'biography': 'Uwe Klein ist seit 2017 Stadtrat und setzt sich für die Förderung des öffentlichen Nahverkehrs ein.',
#   'constituency': 'München-Hadern',
#   'history': [{'kind': 'quote',
#     'content': 'Stadtrat Klein verbessert den Nahverkehr in Hadern.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Klein fahren die Busse und Bahnen besser.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Katrin Meier',
#   'position': 'Abgeordnete',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'biography': 'Katrin Meier ist seit 2022 Abgeordnete und bekannt für ihre umweltpolitischen Initiativen.',
#   'constituency': 'München-Mitte',
#   'history': [{'kind': 'quote',
#     'content': 'Meier bringt Umweltbewusstsein in die Politik.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Meier wird unsere Stadt grüner.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Johannes Berger',
#   'position': 'Bezirksleiter',
#   'party': 'Freie Wähler',
#   'biography': 'Johannes Berger ist ein engagierter Bezirksleiter, der sich für die Verbesserung der Bildungsinfrastruktur einsetzt.',
#   'constituency': 'München-Schwabing',
#   'history': [{'kind': 'quote',
#     'content': 'Berger hat die Schulen in Schwabing modernisiert.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Berger sind unsere Schulen besser ausgestattet.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Lisa Frank',
#   'position': 'Gemeinderätin',
#   'party': 'DIE LINKE',
#   'biography': 'Lisa Frank ist seit 2023 Gemeinderätin und bekannt für ihre Initiativen im Bereich Kulturförderung.',
#   'constituency': 'München-Ramersdorf',
#   'history': [{'kind': 'quote',
#     'content': 'Frank hat viel für die Kultur in Ramersdorf getan.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Frank blüht die Kultur in unserer Gemeinde auf.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Maximilian Huber',
#   'position': 'Landtagsabgeordneter',
#   'party': 'Alternative für Deutschland (AfD)',
#   'biography': 'Maximilian Huber ist seit 2019 Landtagsabgeordneter und setzt sich für eine restriktive Migrationspolitik ein.',
#   'constituency': 'München-Pasing',
#   'history': [{'kind': 'quote',
#     'content': 'Huber setzt sich für eine strengere Migrationspolitik ein.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Huber gibt es mehr Sicherheit in Pasing.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Susanne Richter',
#   'position': 'Bürgermeisterin',
#   'party': 'Parteilos',
#   'biography': 'Susanne Richter ist seit 2020 Bürgermeisterin und engagiert sich stark für den sozialen Wohnungsbau.',
#   'constituency': 'München-Moosach',
#   'history': [{'kind': 'quote',
#     'content': 'Richter baut bezahlbare Wohnungen in Moosach.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Richter gibt es mehr Sozialwohnungen.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Alexander Wolf',
#   'position': 'Stadtrat',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Alexander Wolf ist seit 2018 Stadtrat und bekannt für seine Initiativen im Bereich Digitalisierung.',
#   'constituency': 'München-Milbertshofen',
#   'history': [{'kind': 'quote',
#     'content': 'Wolf bringt Digitalisierung voran.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Wolf wird Milbertshofen digitaler.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Marie Bauer',
#   'position': 'Abgeordnete',
#   'party': 'Christlich-Soziale Union (CSU)',
#   'biography': 'Marie Bauer ist seit 2021 Abgeordnete und setzt sich für die Förderung der lokalen Wirtschaft ein.',
#   'constituency': 'München-Giesing',
#   'history': [{'kind': 'quote',
#     'content': 'Bauer unterstützt die lokale Wirtschaft.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Bauer boomt die Wirtschaft in Giesing.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': '17325499-3f2e-4f94-a6f3-9e016edf4136'},
#  {'name': 'Robert Fischer',
#   'position': 'Ortsvorsteher',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'biography': 'Robert Fischer ist Ortsvorsteher und bekannt für seine umweltpolitischen Maßnahmen.',
#   'constituency': 'München-Bogenhausen',
#   'history': [{'kind': 'quote',
#     'content': 'Fischer setzt sich für die Umwelt ein.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Fischer wird Bogenhausen grüner.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Daniela Wagner',
#   'position': 'Gemeinderätin',
#   'party': 'Freie Wähler',
#   'biography': 'Daniela Wagner ist seit 2019 Gemeinderätin und engagiert sich stark für den Ausbau des öffentlichen Nahverkehrs.',
#   'constituency': 'München-Hadern',
#   'history': [{'kind': 'quote',
#     'content': 'Wagner verbessert den Nahverkehr in Hadern.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Wagner fahren die Busse und Bahnen besser.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Georg Becker',
#   'position': 'Bürgermeister',
#   'party': 'DIE LINKE',
#   'biography': 'Georg Becker ist seit 2022 Bürgermeister und setzt sich für die Modernisierung der städtischen Infrastruktur ein.',
#   'constituency': 'München-Mitte',
#   'history': [{'kind': 'quote',
#     'content': 'Becker modernisiert die Infrastruktur in der Stadt.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Becker geht die Stadtentwicklung voran.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Laura Schmidt',
#   'position': 'Stadträtin',
#   'party': 'Alternative für Deutschland (AfD)',
#   'biography': 'Laura Schmidt ist seit 2020 Stadträtin und bekannt für ihre Initiativen zur Verbesserung der inneren Sicherheit.',
#   'constituency': 'München-Schwabing',
#   'history': [{'kind': 'quote',
#     'content': 'Schmidt setzt sich für mehr Sicherheit in Schwabing ein.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Schmidt fühlen wir uns sicherer in Schwabing.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Monika Hoffmann',
#   'position': 'Bezirksleiterin',
#   'party': 'Parteilos',
#   'biography': 'Monika Hoffmann ist seit 2021 Bezirksleiterin und engagiert sich für den Schutz von Minderheiten.',
#   'constituency': 'München-Ramersdorf',
#   'history': [{'kind': 'quote',
#     'content': 'Hoffmann kämpft für den Schutz von Minderheiten.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Hoffmann geht es Minderheiten besser in Ramersdorf.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Lukas Weber',
#   'position': 'Abgeordneter',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Lukas Weber ist seit 2018 Abgeordneter und bekannt für seine Bemühungen im Bereich der Bildungspolitik.',
#   'constituency': 'München-Pasing',
#   'history': [{'kind': 'quote',
#     'content': 'Weber setzt sich für eine bessere Bildung ein.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Weber sind die Schulen in Pasing besser.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Karin Keller',
#   'position': 'Ortsvorsteherin',
#   'party': 'Christlich-Soziale Union (CSU)',
#   'biography': 'Karin Keller ist Ortsvorsteherin seit 2019 und bekannt für ihre Initiativen im Bereich Stadtentwicklung.',
#   'constituency': 'München-Moosach',
#   'history': [{'kind': 'quote',
#     'content': 'Keller bringt die Stadtentwicklung voran.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Keller wird Moosach schöner.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Felix Braun',
#   'position': 'Landtagsabgeordneter',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'biography': 'Felix Braun ist Landtagsabgeordneter seit 2021 und bekannt für seine umweltfreunDIE LINKEichen Verkehrskonzepte.',
#   'constituency': 'München-Milbertshofen',
#   'history': [{'kind': 'quote',
#     'content': 'Braun fördert umweltfreunDIE LINKEiche Verkehrskonzepte.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Braun ist der Verkehr in Milbertshofen grüner.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Anna Bergmann',
#   'position': 'Stadträtin',
#   'party': 'Freie Wähler',
#   'biography': 'Anna Bergmann ist seit 2017 Stadträtin und setzt sich für die Förderung von Sport- und Freizeitangeboten ein.',
#   'constituency': 'München-Giesing',
#   'history': [{'kind': 'quote',
#     'content': 'Bergmann fördert Sportangebote in Giesing.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Bergmann gibt es mehr Freizeitangebote.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'a9e1478b-5992-409c-9bc0-305eb0ef5d0f'},
#  {'name': 'Markus Klein',
#   'position': 'Bürgermeister',
#   'party': 'DIE LINKE',
#   'biography': 'Markus Klein ist seit 2019 Bürgermeister und bekannt für seine Initiativen zur Förderung der lokalen Kunstszene.',
#   'constituency': 'München-Bogenhausen',
#   'history': [{'kind': 'quote',
#     'content': 'Klein fördert die lokale Kunstszene.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Klein blüht die Kunst in Bogenhausen.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Petra Winkler',
#   'position': 'Ortsvorsteherin',
#   'party': 'Alternative für Deutschland (AfD)',
#   'biography': 'Petra Winkler ist seit 2020 Ortsvorsteherin und setzt sich für eine konservative Familienpolitik ein.',
#   'constituency': 'München-Hadern',
#   'history': [{'kind': 'quote',
#     'content': 'Winkler fördert eine konservative Familienpolitik.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Winkler werden traditionelle Familienwerte in Hadern gestärkt.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Sophie Schwarz',
#   'position': 'Bezirksleiterin',
#   'party': 'Parteilos',
#   'biography': 'Sophie Schwarz ist Bezirksleiterin seit 2021 und engagiert sich für die Förderung von Kultur- und Jugendprojekten.',
#   'constituency': 'München-Mitte',
#   'history': [{'kind': 'quote',
#     'content': 'Schwarz fördert Kultur- und Jugendprojekte.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Schwarz blühen Kulturprojekte in München-Mitte.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Nina Krüger',
#   'position': 'Abgeordnete',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Nina Krüger ist seit 2019 Abgeordnete und bekannt für ihre Initiativen im Bereich der Gesundheitsversorgung.',
#   'constituency': 'München-Schwabing',
#   'history': [{'kind': 'quote',
#     'content': 'Krüger setzt sich für bessere Gesundheitsversorgung ein.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Krüger sind die Gesundheitsdienste in Schwabing besser.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Frank Bauer',
#   'position': 'Ortsvorsteher',
#   'party': 'Christlich-Soziale Union (CSU)',
#   'biography': 'Frank Bauer ist seit 2018 Ortsvorsteher und engagiert sich für die Förderung der lokalen Wirtschaft.',
#   'constituency': 'München-Ramersdorf',
#   'history': [{'kind': 'quote',
#     'content': 'Bauer unterstützt die lokale Wirtschaft in Ramersdorf.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Bauer boomt die Wirtschaft in Ramersdorf.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Eva König',
#   'position': 'Gemeinderätin',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'biography': 'Eva König ist seit 2020 Gemeinderätin und bekannt für ihre umweltpolitischen Maßnahmen.',
#   'constituency': 'München-Pasing',
#   'history': [{'kind': 'quote',
#     'content': 'König setzt sich für die Umwelt in Pasing ein.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank König wird Pasing grüner.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Holger Maier',
#   'position': 'Landtagsabgeordneter',
#   'party': 'Freie Wähler',
#   'biography': 'Holger Maier ist seit 2021 Landtagsabgeordneter und setzt sich für die Verbesserung der Infrastruktur ein.',
#   'constituency': 'München-Moosach',
#   'history': [{'kind': 'quote',
#     'content': 'Maier verbessert die Infrastruktur in Moosach.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Maier sind die Straßen in Moosach besser.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Ulrike Weber',
#   'position': 'Stadträtin',
#   'party': 'DIE LINKE',
#   'biography': 'Ulrike Weber ist seit 2020 Stadträtin und bekannt für ihre Arbeit im Bereich der Kulturförderung.',
#   'constituency': 'München-Milbertshofen',
#   'history': [{'kind': 'quote',
#     'content': 'Weber fördert die Kultur in Milbertshofen.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Weber blüht die Kultur in unserer Stadt.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Christian Neumann',
#   'position': 'Bürgermeister',
#   'party': 'Alternative für Deutschland (AfD)',
#   'biography': 'Christian Neumann ist seit 2021 Bürgermeister und bekannt für seine konservativen Initiativen.',
#   'constituency': 'München-Giesing',
#   'history': [{'kind': 'quote',
#     'content': 'Neumann setzt sich für konservative Werte ein.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Neumann werden konservative Werte in Giesing gestärkt.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'd823effe-1feb-4815-8d09-49e7439f2ff7'},
#  {'name': 'Elena Hoffmann',
#   'position': 'Gemeinderätin',
#   'party': 'Parteilos',
#   'biography': 'Elena Hoffmann ist seit 2022 Gemeinderätin und engagiert sich für soziale Projekte.',
#   'constituency': 'München-Bogenhausen',
#   'history': [{'kind': 'quote',
#     'content': 'Hoffmann fördert soziale Projekte in Bogenhausen.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Hoffmann gibt es mehr soziale Unterstützung.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Jan Wagner',
#   'position': 'Abgeordneter',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Jan Wagner ist seit 2017 Abgeordneter und bekannt für seine Arbeit im Bereich der Digitalisierung.',
#   'constituency': 'München-Hadern',
#   'history': [{'kind': 'quote',
#     'content': 'Wagner bringt Digitalisierung voran.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Wagner wird Hadern digitaler.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Sophia Meier',
#   'position': 'Stadträtin',
#   'party': 'Christlich-Soziale Union (CSU)',
#   'biography': 'Sophia Meier ist seit 2018 Stadträtin und setzt sich für die Förderung von Sport und Freizeit ein.',
#   'constituency': 'München-Mitte',
#   'history': [{'kind': 'quote',
#     'content': 'Meier fördert Sportangebote in München-Mitte.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Meier gibt es mehr Sportmöglichkeiten.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Paul Richter',
#   'position': 'Landtagsabgeordneter',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'biography': 'Paul Richter ist Landtagsabgeordneter seit 2020 und bekannt für seine umweltfreunDIE LINKEichen Initiativen.',
#   'constituency': 'München-Schwabing',
#   'history': [{'kind': 'quote',
#     'content': 'Richter setzt sich für die Umwelt ein.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Richter wird Schwabing grüner.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Melanie Schäfer',
#   'position': 'Bezirksleiterin',
#   'party': 'Freie Wähler',
#   'biography': 'Melanie Schäfer ist seit 2021 Bezirksleiterin und engagiert sich stark für die Bildung.',
#   'constituency': 'München-Ramersdorf',
#   'history': [{'kind': 'quote',
#     'content': 'Schäfer fördert Bildung in Ramersdorf.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Schäfer sind die Schulen besser ausgestattet.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Julian Köhler',
#   'position': 'Gemeinderat',
#   'party': 'DIE LINKE',
#   'biography': 'Julian Köhler ist seit 2022 Gemeinderat und bekannt für seine Initiativen im Bereich der Digitalisierung.',
#   'constituency': 'München-Pasing',
#   'history': [{'kind': 'quote',
#     'content': 'Köhler bringt Digitalisierung nach Pasing.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Köhler wird Pasing digitaler.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Leon Becker',
#   'position': 'Abgeordneter',
#   'party': 'Alternative für Deutschland (AfD)',
#   'biography': 'Leon Becker ist seit 2019 Abgeordneter und setzt sich für eine restriktive Migrationspolitik ein.',
#   'constituency': 'München-Moosach',
#   'history': [{'kind': 'quote',
#     'content': 'Becker setzt sich für strengere Migrationsgesetze ein.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Becker gibt es mehr Sicherheit in Moosach.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Nadine Hofmann',
#   'position': 'Bürgermeisterin',
#   'party': 'Parteilos',
#   'biography': 'Nadine Hofmann ist seit 2020 Bürgermeisterin und bekannt für ihre sozialen Projekte.',
#   'constituency': 'München-Milbertshofen',
#   'history': [{'kind': 'quote',
#     'content': 'Hofmann setzt sich für soziale Projekte ein.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Hofmann gibt es mehr Unterstützung in Milbertshofen.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Michael Weiß',
#   'position': 'Stadtrat',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Michael Weiß ist seit 2017 Stadtrat und bekannt für seine Initiativen zur Verkehrsplanung.',
#   'constituency': 'München-Giesing',
#   'history': [{'kind': 'quote',
#     'content': 'Weiß verbessert die Verkehrsplanung in Giesing.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Weiß ist der Verkehr in Giesing besser.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': '89a608e2-b44b-47b2-bca2-a8bc50f65946'},
#  {'name': 'Clara Wagner',
#   'position': 'Bezirksleiterin',
#   'party': 'Christlich-Soziale Union (CSU)',
#   'biography': 'Clara Wagner ist seit 2019 Bezirksleiterin und engagiert sich für die Förderung von Startups.',
#   'constituency': 'München-Bogenhausen',
#   'history': [{'kind': 'quote',
#     'content': 'Wagner unterstützt Startups in Bogenhausen.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Wagner gibt es mehr Unterstützung für Startups.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Jonas Berg',
#   'position': 'Landtagsabgeordneter',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'biography': 'Jonas Berg ist Landtagsabgeordneter seit 2021 und bekannt für seine umweltpolitischen Maßnahmen.',
#   'constituency': 'München-Hadern',
#   'history': [{'kind': 'quote',
#     'content': 'Berg setzt sich für die Umwelt in Hadern ein.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Berg wird Hadern grüner.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Isabel Fischer',
#   'position': 'Gemeinderätin',
#   'party': 'Freie Wähler',
#   'biography': 'Isabel Fischer ist seit 2022 Gemeinderätin und bekannt für ihre Initiativen im Bereich der Bildung.',
#   'constituency': 'München-Mitte',
#   'history': [{'kind': 'quote',
#     'content': 'Fischer setzt sich für bessere Bildung ein.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Fischer sind die Schulen in München-Mitte besser.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Tom Keller',
#   'position': 'Bürgermeister',
#   'party': 'DIE LINKE',
#   'biography': 'Tom Keller ist seit 2021 Bürgermeister und bekannt für seine Initiativen zur Wirtschaftsförderung.',
#   'constituency': 'München-Schwabing',
#   'history': [{'kind': 'quote',
#     'content': 'Keller unterstützt die Wirtschaft in Schwabing.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Keller boomt die Wirtschaft in Schwabing.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Emma Schneider',
#   'position': 'Ortsvorsteherin',
#   'party': 'Alternative für Deutschland (AfD)',
#   'biography': 'Emma Schneider ist seit 2020 Ortsvorsteherin und setzt sich für eine strengere Migrationspolitik ein.',
#   'constituency': 'München-Ramersdorf',
#   'history': [{'kind': 'quote',
#     'content': 'Schneider setzt sich für strengere Migrationsgesetze ein.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Schneider gibt es mehr Sicherheit in Ramersdorf.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Oliver Neumann',
#   'position': 'Stadtrat',
#   'party': 'Parteilos',
#   'biography': 'Oliver Neumann ist seit 2022 Stadtrat und bekannt für seine Initiativen zur Förderung der lokalen Kunstszene.',
#   'constituency': 'München-Pasing',
#   'history': [{'kind': 'quote',
#     'content': 'Neumann unterstützt die Kunst in Pasing.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Neumann blüht die Kunst in Pasing.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Theresa Klein',
#   'position': 'Abgeordnete',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Theresa Klein ist seit 2018 Abgeordnete und bekannt für ihre Initiativen im Bereich der sozialen Gerechtigkeit.',
#   'constituency': 'München-Moosach',
#   'history': [{'kind': 'quote',
#     'content': 'Klein kämpft für soziale Gerechtigkeit.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Klein gibt es mehr Gerechtigkeit in Moosach.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Heike Braun',
#   'position': 'Bezirksleiterin',
#   'party': 'Christlich-Soziale Union (CSU)',
#   'biography': 'Heike Braun ist seit 2020 Bezirksleiterin und engagiert sich für die Förderung der Infrastruktur.',
#   'constituency': 'München-Milbertshofen',
#   'history': [{'kind': 'quote',
#     'content': 'Braun verbessert die Infrastruktur in Milbertshofen.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Braun sind die Straßen und Brücken besser.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Sven Meier',
#   'position': 'Stadtrat',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'biography': 'Sven Meier ist seit 2021 Stadtrat und bekannt für seine umweltfreunDIE LINKEichen Initiativen.',
#   'constituency': 'München-Giesing',
#   'history': [{'kind': 'quote',
#     'content': 'Meier setzt sich für die Umwelt ein.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Meier wird Giesing grüner.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': '7766051e-759b-4483-be2a-d27fd8522b3f'},
#  {'name': 'Lena Bergmann',
#   'position': 'Gemeinderätin',
#   'party': 'Freie Wähler',
#   'biography': 'Lena Bergmann ist seit 2021 Gemeinderätin und bekannt für ihre Initiativen im Bereich Bildung.',
#   'constituency': 'München-Bogenhausen',
#   'history': [{'kind': 'quote',
#     'content': 'Bergmann setzt sich für bessere Bildung ein.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Bergmann sind die Schulen in Bogenhausen besser.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'David Wolf',
#   'position': 'Bürgermeister',
#   'party': 'DIE LINKE',
#   'biography': 'David Wolf ist seit 2020 Bürgermeister und bekannt für seine wirtschaftspolitischen Initiativen.',
#   'constituency': 'München-Hadern',
#   'history': [{'kind': 'quote',
#     'content': 'Wolf fördert die Wirtschaft in Hadern.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Wolf boomt die Wirtschaft in Hadern.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Anna Lang',
#   'position': 'Bürgermeisterin',
#   'party': 'Christlich-Soziale Union (CSU)',
#   'biography': 'Anna Lang ist seit 2022 Bürgermeisterin und setzt sich für die Förderung der Digitalisierung in der Stadtverwaltung ein.',
#   'constituency': 'München-Altstadt',
#   'history': [{'kind': 'quote',
#     'content': 'Lang bringt Digitalisierung in die Stadtverwaltung.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Lang sind die digitalen Dienstleistungen in Altstadt verbessert worden.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Tobias Schmidt',
#   'position': 'Stadtrat',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Tobias Schmidt ist seit 2019 Stadtrat und engagiert sich für die Verbesserung der Luftqualität in der Stadt.',
#   'constituency': 'München-Ludwigsvorstadt',
#   'history': [{'kind': 'quote',
#     'content': 'Schmidt arbeitet hart an der Verbesserung der Luftqualität.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Schmidt ist die Luft in Ludwigsvorstadt sauberer geworden.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Sophie Peters',
#   'position': 'Bezirksleiterin',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'biography': 'Sophie Peters ist seit 2021 Bezirksleiterin und bekannt für ihre Bemühungen um nachhaltige Stadtentwicklung.',
#   'constituency': 'München-Neuperlach',
#   'history': [{'kind': 'quote',
#     'content': 'Peters setzt sich für nachhaltige Stadtentwicklung ein.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Peters wird Neuperlach grüner und nachhaltiger.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Leonard Müller',
#   'position': 'Abgeordneter',
#   'party': 'Freie Wähler',
#   'biography': 'Leonard Müller ist seit 2020 Abgeordneter und bekannt für seine Initiativen zur Förderung von Startups.',
#   'constituency': 'München-Pasing',
#   'history': [{'kind': 'quote',
#     'content': 'Müller fördert Startups in Pasing.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Müller gibt es mehr Unterstützung für junge Unternehmen.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Jana Wolf',
#   'position': 'Ortsvorsteherin',
#   'party': 'Parteilos',
#   'biography': 'Jana Wolf ist seit 2021 Ortsvorsteherin und engagiert sich für die Verbesserung der sozialen Infrastruktur.',
#   'constituency': 'München-Ramersdorf',
#   'history': [{'kind': 'quote',
#     'content': 'Wolf verbessert die soziale Infrastruktur in Ramersdorf.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Wolf gibt es mehr soziale Unterstützung in unserer Gemeinde.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Maximilian Köhler',
#   'position': 'Gemeinderat',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Maximilian Köhler ist seit 2022 Gemeinderat und bekannt für seine Arbeit im Bereich der Jugendförderung.',
#   'constituency': 'München-Schwabing',
#   'history': [{'kind': 'quote',
#     'content': 'Köhler setzt sich stark für die Jugendförderung ein.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Köhler gibt es mehr Angebote für die Jugend in Schwabing.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Elena Zimmermann',
#   'position': 'Stadträtin',
#   'party': 'Christlich-Soziale Union (CSU)',
#   'biography': 'Elena Zimmermann ist seit 2018 Stadträtin und setzt sich für die Verbesserung der Bildungseinrichtungen ein.',
#   'constituency': 'München-Altstadt',
#   'history': [{'kind': 'quote',
#     'content': 'Zimmermann arbeitet an der Verbesserung der Bildungseinrichtungen.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Zimmermann sind die Schulen in Altstadt besser ausgestattet.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'David Huber',
#   'position': 'Bezirksleiter',
#   'party': 'DIE LINKE',
#   'biography': 'David Huber ist seit 2019 Bezirksleiter und bekannt für seine Initiativen zur Förderung der kulturellen Bildung.',
#   'constituency': 'München-Neuperlach',
#   'history': [{'kind': 'quote',
#     'content': 'Huber fördert kulturelle Bildungsprojekte.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Huber gibt es mehr kulturelle Angebote in Neuperlach.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Verena Schuster',
#   'position': 'Abgeordnete',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'biography': 'Verena Schuster ist seit 2020 Abgeordnete und bekannt für ihre Arbeit im Bereich der Nachhaltigkeit.',
#   'constituency': 'München-Giesing',
#   'history': [{'kind': 'quote',
#     'content': 'Schuster setzt sich für Nachhaltigkeit ein.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Schuster wird Giesing nachhaltiger.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': '53cf3b58-21a1-45ec-ad8c-6977a6d9bbfa'},
#  {'name': 'Felix Neumann',
#   'position': 'Landtagsabgeordneter',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Felix Neumann ist seit 2021 Landtagsabgeordneter und setzt sich für die Förderung der lokalen Wirtschaft ein.',
#   'constituency': 'München-Moosach',
#   'history': [{'kind': 'quote',
#     'content': 'Neumann unterstützt die lokale Wirtschaft in Moosach.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Neumann boomt die Wirtschaft in Moosach.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Claudia Braun',
#   'position': 'Bürgermeisterin',
#   'party': 'Christlich-Soziale Union (CSU)',
#   'biography': 'Claudia Braun ist seit 2022 Bürgermeisterin und setzt sich für die Verbesserung der Infrastruktur und der Verkehrsanbindungen ein.',
#   'constituency': 'München-Ludwigsvorstadt',
#   'history': [{'kind': 'quote',
#     'content': 'Braun arbeitet an der Verbesserung der Infrastruktur.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Braun sind die Verkehrsanbindungen in Ludwigsvorstadt besser geworden.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Sarah Keller',
#   'position': 'Stadträtin',
#   'party': 'Parteilos',
#   'biography': 'Sarah Keller ist seit 2021 Stadträtin und bekannt für ihre Initiativen im Bereich der sozialen Integration.',
#   'constituency': 'München-Ramersdorf',
#   'history': [{'kind': 'quote',
#     'content': 'Keller setzt sich für soziale Integration ein.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Keller gibt es mehr Integrationsangebote in Ramersdorf.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Markus Schiller',
#   'position': 'Ortsvorsteher',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'biography': 'Markus Schiller ist seit 2020 Ortsvorsteher und engagiert sich für den Ausbau von Freizeitangeboten.',
#   'constituency': 'München-Milbertshofen',
#   'history': [{'kind': 'quote',
#     'content': 'Schiller fördert Freizeitangebote in Milbertshofen.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Schiller gibt es mehr Freizeitmöglichkeiten in Milbertshofen.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Laura Müller',
#   'position': 'Gemeinderätin',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Laura Müller ist seit 2019 Gemeinderätin und bekannt für ihre Arbeit im Bereich der Stadtentwicklung.',
#   'constituency': 'München-Schwabing',
#   'history': [{'kind': 'quote',
#     'content': 'Müller arbeitet an der Stadtentwicklung in Schwabing.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Müller entwickelt sich Schwabing weiter.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Nicolas Hoffmann',
#   'position': 'Bezirksleiter',
#   'party': 'Christlich-Soziale Union (CSU)',
#   'biography': 'Nicolas Hoffmann ist seit 2020 Bezirksleiter und setzt sich für den Ausbau der Bildungsangebote ein.',
#   'constituency': 'München-Giesing',
#   'history': [{'kind': 'quote',
#     'content': 'Hoffmann fördert Bildungsangebote in Giesing.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Hoffmann gibt es bessere Bildungsangebote in Giesing.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': '715723ca-2f23-45cd-a654-cad79e310016'},
#  {'name': 'Hannah Fischer',
#   'position': 'Abgeordnete',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'biography': 'Hannah Fischer ist seit 2021 Abgeordnete und bekannt für ihre Arbeit im Bereich der Umweltpolitik.',
#   'constituency': 'München-Pasing',
#   'history': [{'kind': 'quote',
#     'content': 'Fischer setzt sich für Umweltpolitik ein.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Fischer ist Pasing umweltfreunDIE LINKEicher geworden.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Tom Wagner',
#   'position': 'Landtagsabgeordneter',
#   'party': 'Freie Wähler',
#   'biography': 'Tom Wagner ist seit 2022 Landtagsabgeordneter und engagiert sich für die Förderung des länDIE LINKEichen Raums.',
#   'constituency': 'München-Ramersdorf',
#   'history': [{'kind': 'quote',
#     'content': 'Wagner setzt sich für die Förderung des länDIE LINKEichen Raums ein.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Wagner gibt es mehr Unterstützung für den länDIE LINKEichen Raum in Ramersdorf.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Elena Weber',
#   'position': 'Bürgermeisterin',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Elena Weber ist seit 2023 Bürgermeisterin und setzt sich für eine gerechte Stadtentwicklung ein.',
#   'constituency': 'München-Schwabing',
#   'history': [{'kind': 'quote',
#     'content': 'Weber arbeitet an einer gerechteren Stadtentwicklung.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Weber gibt es gerechtere Entwicklungsprojekte in Schwabing.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Paul Berger',
#   'position': 'Stadtrat',
#   'party': 'Christlich-Soziale Union (CSU)',
#   'biography': 'Paul Berger ist seit 2022 Stadtrat und bekannt für seine Arbeit im Bereich der Verkehrspolitik.',
#   'constituency': 'München-Altstadt',
#   'history': [{'kind': 'quote',
#     'content': 'Berger setzt sich für eine bessere Verkehrspolitik ein.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Berger hat sich der Verkehr in Altstadt verbessert.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Lisa Hoffmann',
#   'position': 'Bezirksleiterin',
#   'party': 'Parteilos',
#   'biography': 'Lisa Hoffmann ist seit 2021 Bezirksleiterin und engagiert sich für die Integration von Migranten.',
#   'constituency': 'München-Neuperlach',
#   'history': [{'kind': 'quote',
#     'content': 'Hoffmann setzt sich für die Integration von Migranten ein.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Hoffmann gibt es mehr Integrationsangebote in Neuperlach.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Julius König',
#   'position': 'Abgeordneter',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'biography': 'Julius König ist seit 2021 Abgeordneter und bekannt für seine Initiativen im Bereich des sozialen Wohnungsbaus.',
#   'constituency': 'München-Pasing',
#   'history': [{'kind': 'quote',
#     'content': 'König arbeitet am sozialen Wohnungsbau.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank König gibt es mehr soziale Wohnungen in Pasing.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Miriam Schneider',
#   'position': 'Landtagsabgeordnete',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Miriam Schneider ist seit 2018 Landtagsabgeordnete und engagiert sich für die Verbesserung des Gesundheitswesens.',
#   'constituency': 'München-Milbertshofen',
#   'history': [{'kind': 'quote',
#     'content': 'Schneider setzt sich für bessere Gesundheitsversorgung ein.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Schneider ist die Gesundheitsversorgung in Milbertshofen besser geworden.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Thomas Müller',
#   'position': 'Ortsvorsteher',
#   'party': 'Christlich-Soziale Union (CSU)',
#   'biography': 'Thomas Müller ist seit 2021 Ortsvorsteher und bekannt für seine Arbeit im Bereich der Stadtplanung.',
#   'constituency': 'München-Giesing',
#   'history': [{'kind': 'quote',
#     'content': 'Müller arbeitet an der Stadtplanung in Giesing.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Müller gibt es bessere Stadtplanung in Giesing.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': '10782899-2e91-4769-baed-25aae17a1839'},
#  {'name': 'Nina Fischer',
#   'position': 'Gemeinderätin',
#   'party': 'Freie Wähler',
#   'biography': 'Nina Fischer ist seit 2020 Gemeinderätin und setzt sich für die Förderung der lokalen Kultur ein.',
#   'constituency': 'München-Schwabing',
#   'history': [{'kind': 'quote',
#     'content': 'Fischer fördert lokale Kultur in Schwabing.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Fischer gibt es mehr kulturelle Angebote in Schwabing.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Lukas Braun',
#   'position': 'Stadtrat',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Lukas Braun ist seit 2021 Stadtrat und bekannt für seine Arbeit im Bereich der Energiepolitik.',
#   'constituency': 'München-Moosach',
#   'history': [{'kind': 'quote',
#     'content': 'Braun setzt sich für bessere Energiepolitik ein.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Braun gibt es nachhaltigere Energiequellen in Moosach.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Marlene Weber',
#   'position': 'Bürgermeisterin',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'biography': 'Marlene Weber ist seit 2022 Bürgermeisterin und engagiert sich für den Ausbau der sozialen Einrichtungen.',
#   'constituency': 'München-Ludwigsvorstadt',
#   'history': [{'kind': 'quote',
#     'content': 'Weber arbeitet am Ausbau sozialer Einrichtungen.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Weber gibt es mehr soziale Einrichtungen in Ludwigsvorstadt.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Jakob Schmidt',
#   'position': 'Bezirksleiter',
#   'party': 'Freie Wähler',
#   'biography': 'Jakob Schmidt ist seit 2019 Bezirksleiter und bekannt für seine Arbeit im Bereich der Verkehrsplanung.',
#   'constituency': 'München-Pasing',
#   'history': [{'kind': 'quote',
#     'content': 'Schmidt arbeitet an der Verkehrsplanung in Pasing.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Schmidt gibt es bessere Verkehrslösungen in Pasing.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Friedrich Meyer',
#   'position': 'Abgeordneter',
#   'party': 'Christlich-Soziale Union (CSU)',
#   'biography': 'Friedrich Meyer ist seit 2020 Abgeordneter und setzt sich für den Ausbau der Infrastruktur ein.',
#   'constituency': 'München-Milbertshofen',
#   'history': [{'kind': 'quote',
#     'content': 'Meyer fördert den Ausbau der Infrastruktur.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Meyer gibt es mehr Infrastrukturprojekte in Milbertshofen.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Hannah Berger',
#   'position': 'Stadträtin',
#   'party': 'Parteilos',
#   'biography': 'Hannah Berger ist seit 2021 Stadträtin und bekannt für ihre Initiativen im Bereich der Jugendförderung.',
#   'constituency': 'München-Ramersdorf',
#   'history': [{'kind': 'quote',
#     'content': 'Berger setzt sich für mehr Jugendförderung ein.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Berger gibt es mehr Angebote für die Jugend in Ramersdorf.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Alexander Lang',
#   'position': 'Ortsvorsteher',
#   'party': 'Sozialdemokratische Partei Deutschlands (SPD)',
#   'biography': 'Alexander Lang ist seit 2018 Ortsvorsteher und engagiert sich für die Förderung der lokalen Wirtschaft.',
#   'constituency': 'München-Schwabing',
#   'history': [{'kind': 'quote',
#     'content': 'Lang fördert die lokale Wirtschaft in Schwabing.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Lang hat sich die Wirtschaft in Schwabing verbessert.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'},
#  {'name': 'Amelie Fischer',
#   'position': 'Gemeinderätin',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'biography': 'Amelie Fischer ist seit 2022 Gemeinderätin und setzt sich für nachhaltige Stadtentwicklung ein.',
#   'constituency': 'München-Neuperlach',
#   'history': [{'kind': 'quote',
#     'content': 'Fischer arbeitet an nachhaltiger Stadtentwicklung.',
#     'header': 'Ein Zitat des Politikers'},
#    {'kind': 'quote',
#     'content': 'Dank Fischer gibt es nachhaltige Projekte in Neuperlach.',
#     'header': 'Ein Zitat des Politikers'}],
#   'photo': 'standard'}]

# %%
with open("database.json", mode="w", encoding="utf-8") as f:
    json.dump(obj=dic, fp=f, ensure_ascii=False)
